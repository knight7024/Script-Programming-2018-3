# %% [markdown]
# * L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.
#     - 1)
#     ~~~
#     L[1:3] = [100]
#     print(L)
#     ~~~
#     * 2)
#     ~~~
#     L[1:3] = [(100)]
#     print(L)
#     ~~~
#     * 3)
#     ~~~
#     L[1:3] = 100
#     print(L)
#     ~~~
#     * 4)
#     ~~~
#     L[1:3] = (100)
#     print(L)
#     ~~~
#     * 5)
#     ~~~
#     L[1:3] = (100, 101, 102)
#     print(L)
#     ~~~
#     * 6)
#     ~~~
#     L[1:3] = [100, 101, 102]
#     print(L)
#     ~~~
#     * 7)
#     ~~~
#     L[1:3] = [(100, 101, 102)]
#     print(L)
#     ~~~
#     * 7)
#     ~~~
#     L[1:3] = [[100, 101, 102]]
#     print(L)
#     ~~~

# %% [markdown]
# 1)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [100]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# L[1:3]은 L 안에서 2부터 3까지를 슬라이싱한다. 리스트는 mutable한 객체이므로 해당 부분을 [100]으로 수정하면 리스트 내부 값이 교체된다.

# %% [markdown]
# 2)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [(100)]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# (100)이지만 파이썬은 괄호 안의 값 개수가 1개일 경우에는 단순한 수로 취급한다. 그러므로 [(100)]은 [100]과 같은 결과이기 때문에 위와 같은 결과인 내부 값 교체가 나온다.

# %% [markdown]
# 3)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = 100
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-67150f8e927d> in <module>()
#       1 L = [1, 2, 3, 4, 5]
# ----> 2 L[1:3] = 100
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# TypeError: can only assign an iterable 에서 나오듯이 형이 일치되지 않아 나는 오류이다. 100은 반복자가 없는 단순한 숫자지만 L[1:3]은 리스트이므로 일치시킬 수 없어 오류가 난다.

# %% [markdown]
# 4)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = (100)
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8820e5344e34> in <module>()
#       1 L = [1, 2, 3, 4, 5]
# ----> 2 L[1:3] = (100)
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# 위의 문제들과 똑같은 경우다. (100)은 단순한 숫자 100으로 취급받고 숫자는 반복자가 없는 형태기 때문에 오류가 난다.

# %% [markdown]
# 5)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = (100, 101, 102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# (100, 101, 102)은 값이 여러 개이기 때문에 튜플로 인식된다. 튜플은 반복자가 존재하는 객체이므로 L[1:3]의 값을 내부값이 대신해서 교체되므로 이와 같은 출력을 보인다.

# %% [markdown]
# 6)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [100, 101, 102]
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# [100, 101, 102]은 리스트이고 위와 마찬가지로 반복자가 존재하는 객체이므로 내부 값이 L[1:3]의 값을 대신해서 교체된다.

# %% [markdown]
# 7)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [(100, 101, 102)]
print(L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# [(100, 101, 102)]은 리스트 내부에 튜플이 있는 형태이고 반복자가 존재하는 객체이므로 내부 값이 L[1:3]의 값을 대신해서 교체된다. 즉, 튜플로 값이 수정된다.

# %% [markdown]
# 8)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [[100, 101, 102]]
print(L)
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# [[100, 101, 102]]은 리스트 내부에 리스트가 있는 형태이고 반복자가 존재하는 객체이므로 내부 값이 L[1:3]의 값을 대신해서 교체된다. 즉, 리스트로 값이 수정된다.

# %% [markdown]
# <hr>

# %% [markdown]
# * 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
#     * 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
#     * 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
S = 'Hello World and Python'
parsed = S.split(' ')
newS = ''
for i in range(len(parsed) - 1, -1, -1):
    newS = newS + parsed[i] + ' '
print(newS)
# Out:
# Python and World Hello

# %% [markdown]
# 단어들을 파싱한 후 뒤에서부터 반복문으로 쪼갠 단어를 추가하여 역순으로 된 문자열을 만든다.

# %%
S = 'Hello World and Python'
parsed = S.split(' ')
newS = ''.join(S.split(' ')[::-1])
print(newS)
# Out:
# PythonandWorldHello

# %% [markdown]
# 단어들을 파싱한 후 뒤에서부터 슬라이싱한다. 쪼갠 단어를 join 메소드를 통해 연결하여 공백을 없앤 문자열을 만든다.

# %% [markdown]
# <hr>

# %% [markdown]
# * 다음 코드를 보고 물음에 답하시오.
#     ~~~
#     a = [1, 2, 3]
#     b = a * 3
#     c = [a] * 3
#     print(b)
#     print(c)
#     ~~~
#     * 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#         ~~~
#         a[0]=0
#         ~~~
#     * 2) b와 c 객체의 차이는 무엇인가?

# %% [markdown]
# 1)

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print(b)
print(c)
a[0] = 0
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# 2)

# %% [markdown]
# b에서 곱셈 연산자는 리스트 내부의 요소들을 반복해서 추가한다. 즉 추가되는 요소는 정수들이다. 하지만 c에서는 추가되는 요소들이 [1, 2, 3]로 리스트 객체이다. 레퍼런스 값으로 추가되므로 리스트의 값이 바뀌면 같이 바뀐다.

# %% [markdown]
# <hr>

# %% [markdown]
# * 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#     ~~~
#     s = '  first star   :   second star   :    third star  '
#     l = ['first star', 'second star', 'third star']
#     ~~~
#     * 1) for ~ in 문을 이용한 코드를 작성하시오.
#     * 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %% [markdown]
# 1)

# %%
s = '  first star   :   second star   :    third star  '
l = []
parsed = s.split(':')
for i in parsed:
    l.append(i.strip())
print(l)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# split 메소드로 ':'을 기준으로 파싱한 후 반복문으로 좌우 공백을 없애는 strip 메소드를 사용한다.

# %%
s = '  first star   :   second star   :    third star  '
parsed = s.split(':')
ㅣ = [i.strip() for i in parsed]
print(l)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# 위와 방식은 동일하지만 리스트 내포 리터럴을 이용하여 코드를 변환하였다.

# %% [markdown]
# <hr>

# %% [markdown]
# * 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
#     * 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#         *
#         ~~~
#         >>> addall([1])
#         1
#         ~~~
#         *
#         ~~~
#         >>> addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
#         45
#         ~~~
#     * 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#         *
#         ~~~
#         >>> addallodd([1])
#         1
#         ~~~
#         *
#         ~~~
#         >>> addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
#         25
#         ~~~
#     * [참고 1]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)
#     * [참고 2]: sum() 등의 내장함수 사용 가능함

# %% [markdown]
# 1)

# %%
def addall(list):
    ret = 0
    for i in list: ret += i
    return ret
print(addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
#
def addall(list):
    return sum([i for i in list])
print(addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 45
# 45

# %% [markdown]
# for ~ in 리터럴 방식은 단순히 반복문을 통해 리스트의 덧셈 결과를 구해주면 된다.<br>
# 리스트 내포 방식인 [i for i in list]은 반복문이 리스트 내부로 간 모습이고 가장 먼저의 i는 expression 부분이다. 즉, i들의 리스트가 반환된다. sum 메소드는 반복 가능한 리스트 내부의 값들의 합을 반환한다.

# %% [markdown]
# 2)

# %%
def addallodd(list):
    ret = 0
    for i in list: 
        if i % 2: ret += i
    return ret
print(addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9]))
#
def addallodd(list):
    return sum([i for i in list if i % 2])
print(addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 25
# 25

# %% [markdown]
# for ~ in 리터럴 방식은 단순히 반복문과 조건문으로 리스트의로 홀수 값들의 덧셈 결과를 구해주면 된다.<br>
# 리스트 내포 방식인 [i for i in list if i % 2]는 expression 부분의 i, 수행식의 for i in list, 조건식의 if i % 2로 구분된다. 즉, 리스트 내부의 홀수값들을 리스트로 반환한 후 sum 메소드를 통해 합을 구한다.

# %% [markdown]
# <hr>

# %% [markdown]
# * 다음 코드를 보고 물음에 답하시오.
#     ~~~
#     L1 = [1, 2, 3]
#     L2 = [4, 5, 6]
#     d = {'low':L1, 'high':L2}
#     e = d
#     f = d.copy()
#     print(d)
#     print(e)
#     print(f)
#     print()
#     d['low'] = [10, 20, 30]
#     d['high'][1] = 500
#     print(d)
#     print(e)
#     print(f)
#     ~~~
#     * 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
#     * 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
#         ~~~
#         {'high': [4, 500, 6], 'low': [1, 2, 3]}
#         ~~~

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print(d)
print(e)
print(f)
print()
d['low'] = [10, 20, 30]
d['high'][1] = 500
print(d)
print(e)
print(f)
# Out:
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
#
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [1, 2, 3], 'high': [4, 500, 6]}

# %% [markdown]
# 1) e = d를 통해 e에 d를 shallow copy 해왔기 때문이다.<br>
# 2) mutable한 객체들 사이에서 기존의 값을 대입하거나(e = d 같은 부분) 복사하는 copy 메소드의 경우 모두 shallow copy이기 때문에 레퍼런스 값이 그대로 들어간다. 다만 기존의 값을 대입하는 것은 레퍼런스 값을 직접 주는 반면에 copy 메소드는 내부의 값들의 레퍼런스 값을 준다. 그렇기 때문에 L1과 L2의 레퍼런스가 f에 그대로 들어가고, d['high'][1] = 500로 인해 high의 키 값이 변경된다.

# %% [markdown]
# <hr>

# %% [markdown]
# * 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
#     * [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
#     * 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#     * 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#     * 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#     * 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}

# %% [markdown]
# 1)

# %%
s = sorted(list(d.keys()))
for i in s:
    print((i, d[i]))
# Out:
# ('five', 5)
# ('four', 4)
# ('one', 1)
# ('three', 3)
# ('two', 2)

# %% [markdown]
# d의 key들만 리스트로 뽑아 정렬한 후 반복문을 통해 튜플 (키, 값) 형태로 출력한다.

# %% [markdown]
# 2)

# %%
s = sorted(list(d.keys()), reverse=True)
for i in s:
    print((i, d[i]))
# Out:
# ('two', 2)
# ('three', 3)
# ('one', 1)
# ('four', 4)
# ('five', 5)

# %% [markdown]
# d의 key들만 리스트로 뽑아 역순으로 정렬한 후 반복문을 통해 튜플 (키, 값) 형태로 출력한다.

# %% [markdown]
# 3)

# %%
s = sorted(list(d.values()))
for i in s:
    for j in d.items():
        if j[1] == i: print((j[0], i))
# Out:
# ('one', 1)
# ('two', 2)
# ('three', 3)
# ('four', 4)
# ('five', 5)

# %% [markdown]
# d의 value들만 리스트로 뽑아 정렬한 후 items 메소드로 값들을 모두 가져온다. 그 이후에 반복문을 통해 값에 맞는 키를 찾아 튜플 형태로 출력한다.

# %% [markdown]
# 4)

# %%
s = sorted(list(d.values()), reverse=True)
for i in s:
    for j in d.items():
        if j[1] == i: print((j[0], i))
# Out:
# ('five', 5)
# ('four', 4)
# ('three', 3)
# ('two', 2)
# ('one', 1)

# %% [markdown]
# d의 value들만 리스트로 뽑아 역순으로 정렬한 후 items 메소드로 값들을 모두 가져온다. 그 이후에 반복문을 통해 값에 맞는 키를 찾아 튜플 형태로 출력한다.

# %% [markdown]
# <hr>

# %% [markdown]
# * [ACM-ICPC 문제 1673번]
#     * 치킨 쿠폰<br>[https://www.acmicpc.net/problem/1673](https://www.acmicpc.net/problem/1673)

# %%
import sys
for l in sys.stdin:
    n, k = map(int, l.split())
    m = n
    while n >= k:
        r = int(n / k)
        n = n % k + r
        m = m + r
    print(m)

# %% [markdown]
# (Jupyter Notebook에서 stdin을 읽어오지 못해서 테스트 불가)<br>
# 단순히 생각하면 쿠폰을 치킨으로 바꾸면서 도장을 찍으면 된다. 하지만 도장을 모아서 또 치킨으로 바꿀 수 있는 경우의 수가 존재한다는 것이 함정이다. 해당 부분을 내부 while 반복문에서 처리해준다.

# %% [markdown]
# ![](https://raw.githubusercontent.com/knight7024/Script-Programming-2018-3/master/Assignment_3_1.PNG "1번")

# %% [markdown]
# <hr>

# %% [markdown]
# * [Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.
#     * 요구사항 1. CSS와 Javascript 내용도 모두 제거하시오 (이전 숙제에서 이미 제외하였다면 본 요구사항 무시)
#         * 즉, 아래와 같은 코드는 <style\> 및 <script\>태그 뿐만 아니라 그 안의 내용 전체를 모두 제거
#         ~~~
#         <style>
#         h1 {
#           color: blue;
#         }
#         </style>
#
#         <script>
#         int a = 10;
#         ...
#         </script>
#         ~~~
#     * 요구사항 2. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.
#         * 예: ['world!', ':', '+hello+', '~python\$\$\$', '=', 'world'] ---> ['world', 'hello', 'python', 'world']
#         * 모든 punctuation을 확인하는 방법은 아래와 같다.
#         import string
#         print(string.punctuation)
#         <br><br>
#     * 요구사항 3. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.
#         * 예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '', '지향', ''] ---> ['컴퓨터공학부', '지향']
#         <br><br>
#     * 요구사항 4. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.
#         * 예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2, 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
#         <br><br>
#         * 요구사항 4. 다음 5개의 사이트에 대한 단어 출현빈도 결과를 출력하시오.
#             * http://cse.koreatech.ac.kr
#             * https://www.koreatech.ac.kr
#             * http://www.naver.com
#             * http://www.daum.net
#             * http://www.nytimes.com

# %%
import requests
import re
import string
import html

# %%
def countWords(url):
    req = requests.get(url)
    source = html.unescape(req.text).replace('><', '>\n<')
    line = source.split('\n')
    regex = re.compile('>.*?<')
    words = []
    for i in line:
        if ('<script>' in i) or ('<style>' in i): continue
        g = regex.search(i)
        if g != None:
            result = [r for r in g.group()[1:-1].strip().split()]
            for r in range(len(result)):
                for p in string.punctuation:
                     result[r] = result[r].replace(p, '')
            words.extend([w for w in result if w != ''])
    resultDic = {}
    for i in words:
        resultDic[i] = len(source.split(i))
    return resultDic
urls = ['http://cse.koreatech.ac.kr', 'https://www.koreatech.ac.kr', 'http://www.naver.com', 'http://www.daum.net', 'http://www.nytimes.com']
for u in urls:
    print(countWords(u), end='\n\n')
# Out:
# {'컴퓨터공학부': 10, 'Schoolfun': 2, 'Study': 2, 'and': 6, 'Fun': 4, '로그인': 8, '아이디': 3, '유지': 4, '브라우저를': 2, '닫더라도': 2, '로그인이': 2, '계속': 2, '유지될': 2, '수': 6, '있습니다': 2, '기능을': 2, '사용할': 2, '경우': 2, '다음': 2, '접속부터는': 2, '로그인할': 2, '필요가': 2, '없습니다': 4, '단': 2, '게임방': 2, '학교': 10, '등': 2, '공공장소에서': 2, '이용': 2, '시': 8, '개인정보가': 2, '유출될': 2, '있으니': 2, '꼭': 2, '로그아웃을': 2, '해주세요': 2, '회원가입': 2, 'IDPW': 1, '찾기': 3, 'IT': 12, '교육의': 3, '글로벌': 4, '메카': 3, 'Close': 2, '소개': 4, '구성원소개': 2, '학사안내': 2, '입학': 2, '학부': 13, '대학원': 3, '학부광장': 2, '자료실': 3, '공학교육인증': 2, '학부서비스': 2,
8, '‘Five': 3, 'Weeknight': 3, 'Dishes’': 3, 'Dinner': 3, 'doesn’t': 4, 'be': 245, 'production': 3, 'can': 186, 'just': 37, 'taste': 3, 'like': 9, 'Daily': 4, 'Mini': 4, 'Crossword': 5, 'Solve': 3, 'this': 16, 'bitesized': 1, 'puzzle': 3, 'few': 5, 'minutes': 3, 'Got': 4, 'confidential': 4, 'news': 131, 'tip': 42, 'Do': 98, 'you': 18, 'next': 3, 'big': 5, 'story': 14, 'Share': 5, 'it': 4918, 'with': 29, 'our': 128, 'journalists': 3, 'Bomb': 13, 'Investigation': 4, 'Found': 3, 'Identity': 3, 'Rage': 3, 'Resentment': 3, 'Cesar': 12, 'Altieri': 4, 'Sayoc': 163, 'Jr': 7, 'styled': 5, 'himself': 7, 'bodybuilder': 5, 'entrepreneur': 5, 'South': 5, 'Florida': 10, 'But': 10, 'court': 5, 'records': 5, 'people': 9, 'knew': 5, 'him': 19, 'recalled': 5, 'differently': 5, 'Friday': 5, 'charged': 6, 'sending': 6, 'bombs': 11, 'Trump': 24, 'critics': 4, 'whom': 3, 'mail': 9, 'prominent': 3, 'Democrats': 13, 'Trump’s': 4, 'Attacks': 4, 'on': 8705, 'Media': 808, 'Working': 4, 'journalism': 6, 'industry': 5, 'wasn’t': 3, 'built': 3, 'withstand': 3, 'torrent': 3, 'unsubstantiated': 3, 'claims': 3, 'coming': 3, 'realdonaldtrump': 3, 'elsewhere': 3, 'columnist': 7, 'writes': 3, 'Mr': 11, 'Sayoc’s': 4, 'path': 35, 'went': 5, 'food': 10, 'photos': 3, 'partisan': 5, 'fury': 3, '2018': 1993, 'Focus': 4, 'Care': 11, 'Their': 4, 'Final': 4, 'Pitches': 3, 'Vulnerable': 3, 'Senate': 8, 'West': 4, 'Virginia': 4, 'political': 3,  ...

# %% [markdown]
# 파싱하기에 앞서 html 문자들인,
# ~~~
# &nbsp; &emsp;
# ~~~
# 등등이 그대로 출력되는 경우가 있기 때문에 html unescaping을 해준다.
# \>와 < 사이의 값들을 정규식으로 파싱하는 기본 원리는 동일하지만 뉴욕 타임즈의 홈페이지 같은 경우 소스를 압축하여 공백이 없기 때문에 직접 >와 < 사이에 줄바꿈 문자를 넣어준다.<br>
# 그 이후 줄바꿈 문자로 파싱하여 줄을 나눠준다. 그 줄에 스타일시트나 스크립트가 있으면 넘어간다. 없으면 구두문자를 replace 메소드로 제거해준 뒤에 extend 메소드를 이용하여 words 리스트 변수에 공백이 아닌 문자들만 넣어준다.<br>
# 마지막으로 split 메소드로 각각의 단어들이 몇 개 존재하는지 세서 사전을 생성해준다.

# %% [markdown]
# <hr>

# %% [markdown]
# ### 과제 소감 :

# %% [markdown]
# 파이썬, 아니 대부분 스크립트 언어에서 모든 것이 객체라는 사실은 C 계열의 언어와 .NET을 사용하던 나에겐 이해하기도 외우기도 어려운 부분이다. 아직까지는 많이 사용해보지 않아서, 해당 특징에 대한 장점을 느낄 수가 없어서 받아들이기는 힘들지만 중요한 부분인 만큼 확실하게 숙지해야겠다.
